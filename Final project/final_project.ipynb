# %%
import numpy as np
import pandas as pd
import lxml
pd.options.display.max_rows = 20
np.set_printoptions(precision = 4, suppress = True)

# %%
html_file_path = 'your_file.html'

try:
    # Read HTML file and extract tables
    tables = pd.read_html(html_file_path)

    # Assuming you want the first table, you can access it like this
    if tables:
        df = tables[0]
        print(df)
    else:
        print("No tables found in the HTML file.")

except Exception as e:
    print(f"Error: {e}")
# Out:
#     Jornada           Fecha Horario Localidad Puesto  Adversario  \
# 0         1  sáb 24/08/2019   18:00         A   (1.)         NaN
# 1         2  sáb 31/08/2019   20:45         H   (7.)         NaN
# 2         3  sáb 14/09/2019   15:00         A   (2.)         NaN
# 3         4  sáb 21/09/2019   18:00         H   (3.)         NaN
# 4         5  mar 24/09/2019   21:00         A   (2.)         NaN
# ..      ...             ...     ...       ...    ...         ...
# 33       34  lun 20/07/2020   21:45         H   (1.)         NaN
# 34       35  jue 23/07/2020   19:30         A   (1.)         NaN
# 35       36  dom 26/07/2020   21:45         H   (1.)         NaN
# 36       37  mié 29/07/2020   21:45         A   (1.)         NaN
# 37       38  sáb 01/08/2020   20:45         H   (1.)         NaN
#
#            Adversario.1 Sistema de juego espectadores Resultado
# 0           Parma (11.)   4-3-3 ofensivo       20.814       0:1
# 1          Nápoles (3.)   4-3-3 ofensivo       39.203       4:3
# 2      Fiorentina (16.)   4-3-3 ofensivo       40.312       0:0
# 3   Hellas Verona (11.)   4-3-3 ofensivo       39.945       2:1
# 4         Brescia (11.)          4-3-1-2       14.000       1:2
# ..                  ...              ...          ...       ...
# 33           Lazio (4.)   4-3-3 ofensivo            x       2:1
# 34        Udinese (16.)   4-3-3 ofensivo            x       2:1
# 35      Sampdoria (14.)   4-3-3 ofensivo            x       2:0
# 36       Cagliari (14.)   4-3-3 ofensivo            x       2:0
# 37         AS Roma (5.)   4-3-3 ofensivo            x       1:3
#
# [38 rows x 10 columns]

# %%
from fake_useragent import UserAgent
import requests

# Create a UserAgent object
ua = UserAgent()

# Get a random user agent string
user_agent = ua.random
print(f"Using User-Agent: {user_agent}")

# Set the User-Agent header in your request
headers = {'User-Agent': user_agent}

# Replace 'your_url' with the actual URL you want to access
url = 'https://www.google.com/search?q=real+madris+barca+2019&oq=real+madris+barca+2019&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIGCAEQLhhA0gEJMjI1OTFqMGoxqAIAsAIA&sourceid=chrome&ie=UTF-8#sie=m;/g/11hz2kf__r;2;/m/09gqx;dt;fp;1;;;'

# Send a request with the fake User-Agent
response = requests.get(url, headers=headers)

try:
    # Read HTML file and extract tables
    tables = pd.read_html(response.content)


    # Assuming you want the first table, you can access it like this
    if tables:
        df = tables[5]
        display(df)
    else:
        print("No tables found in the HTML file.")

except Exception as e:
    print(f"Error: {e}")
# Out:
# Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.69
# Error: list index out of range

# %%
file = 'Big_5_European_Leagues_Stats.csv'

df = pd.read_csv(file)

df.head(10)
# Out:
#    Rk            Squad  Country  LgRk  MP   W  D  L  GF  GA  ...  Pts  Pts/G  \
# 0   1  Manchester City  eng ENG     1  29  22  4  3  68  18  ...   70   2.41
# 1   2        Liverpool  eng ENG     2  29  21  6  2  75  20  ...   69   2.38
# 2   3    Bayern Munich   de GER     1  27  20  3  4  81  28  ...   63   2.33
# 3   4      Real Madrid   es ESP     1  29  20  6  3  59  25  ...   66   2.28
# 4   5        Paris S-G   fr FRA     1  29  20  5  4  59  27  ...   65   2.24
# 5   6            Milan   it ITA     1  30  20  6  4  56  29  ...   66   2.20
# 6   7          Chelsea  eng ENG     3  28  17  8  3  57  19  ...   59   2.11
# 7   8         Dortmund   de GER     2  27  18  3  6  67  38  ...   57   2.11
# 8   9           Napoli   it ITA     2  30  19  6  5  53  22  ...   63   2.10
# 9  10            Inter   it ITA     3  29  17  9  3  62  24  ...   60   2.07
#
#      xG   xGA   xGD  xGD/90     Last 5 Attendance  \
# 0  66.9  21.2  45.7    1.58  W L W W D     52,681
# 1  72.0  27.6  44.4    1.53  W W W W W     53,459
# 2  73.1  27.4  45.7    1.69  W W D D W     24,214
# 3  53.4  32.8  20.5    0.71  W W W W L     38,892
# 4  55.1  29.8  25.3    0.87  L W L W L     40,513
# 5  47.8  29.4  18.4    0.61  D D W W W     35,359
# 6  46.7  24.8  21.9    0.78  W W W W W     37,932
# 7  48.4  33.9  14.5    0.54  W D W W D     29,859
# 8  46.9  22.3  24.7    0.82  D W L W W     22,237
# 9  60.2  30.8  29.4    1.01  L D W D D     36,644
#
#                       Top Team Scorer        Goalkeeper
# 0  Riyad Mahrez, Raheem Sterling - 10           Ederson
# 1                  Mohamed Salah - 20           Alisson
# 2             Robert Lewandowski - 31      Manuel Neuer
# 3                  Karim Benzema - 22  Thibaut Courtois
# 4                  Kylian Mbappé - 15      Keylor Navas
# 5  Olivier Giroud, Rafael Leão... - 8      Mike Maignan
# 6                     Mason Mount - 8     Edouard Mendy
# 7                 Erling Haaland - 16      Gregor Kobel
# 8                 Victor Osimhen - 11      David Ospina
# 9               Lautaro Martínez - 14  Samir Handanović
#
# [10 rows x 21 columns]
